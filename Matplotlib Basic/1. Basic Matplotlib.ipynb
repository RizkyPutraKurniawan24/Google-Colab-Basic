# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#sample data
x1 = [1, 3, 5, 7, 9, 11]
y1 = [2, 6, 4, 10, 8, 12]

fig, ax = plt.subplots()
ax.plot(x1, y1)
plt.show()

# %%
x2 = [1, 3, 5, 7, 9, 11]
y2 = [2, 6, 4, 10, 8, 12]

plt.plot(x2, y2)
plt.show()
